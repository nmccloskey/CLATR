# %% [markdown]
# # CLATR - Computational Linguistic Analysis of Text for Research
#
# This notebook runs lexical, morphosyntactic, phonological, and semantic analyses on text samples, followed by clustering.
# Follow the instructions below to upload your data and run the analyses.

# %%
# Run this cell (shift + enter) to upload files from local system to Google Colab.
from google.colab import files
import os
uploaded = files.upload()

# %%
# Run this cell if you need to clear out all your data.
import shutil
shutil.rmtree('directory_name')

# %%
# The GitHub repository must be cloned into Colab.
# !git clone https://github.com/nmccloskey/CLATR.git

# %%
# Directory is switched and files accessed.
# %cd CLATR
uploaded_files = {filename: f'/content/{filename}' for filename in uploaded.keys()}

# %%
# Now the program has to read the files.
from utils.read_files import read_input_files
samples = read_input_files(uploaded_files)

# %%
### LOCAL read_files.py DEV
# import os
# path = 'data/input/'
# uploaded_files = {}
# for file in os.listdir(path):
#     uploaded_files[file] = path + file
from utils.read_files import read_input_files
samples = read_input_files(uploaded_files)
# Out:
# Reading Files: 100%|██████████| 5/5 [00:01<00:00,  3.61it/s]

# %%
samples
# Out:
# {'GenAIinCompLing.cha': "The rise of generative AI has really changed the landscape of\nIn the past, much of the work in computational linguistics was\nResearchers would create explicit grammar rules for machines to\nThis was very time-consuming and often not flexible enough for\nGenerative AI models, like GPT, have shifted the focus toward\nThese models use massive amounts of text data to learn patterns and\nOne of the major advantages of this approach is that it doesn't rely\nInstead, it learns from the data itself, allowing for greater\nThis flexibility has improved performance in tasks like machine\nHowever, there are still some challenges, particularly around\nThese models are often described as black boxes because it's hard\nAdditionally, they can perpetuate biases that exist in the training\nDespite these challenges, generative AI has pushed computational\nWe're now able to tackle tasks that were once thought too complex\nBut it's important to continue refining these systems t
# ...
