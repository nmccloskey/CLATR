# %% [markdown]
# # CLATR - Computational Linguistic Analysis of Text for Research
#
# This notebook runs a battery of linguistic analyses on text samples, including the lexical, morphosyntactic, phonological, and semantic levels.
# Follow the instructions below to upload your data and run the analyses.

# %%
# Run this cell (shift + enter) to upload files from local system in Google Colab.
from google.colab import files
uploaded = files.upload()
# Now the program has to read the files.
from utils.read_files import read_input_files
samples = read_input_files(uploaded)
